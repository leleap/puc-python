# %% [markdown]
# # PUC Minas
# ## Pós-Graduação em Ciência de Dados: Saúde e IA
# ### Atividade Prática
# ### Valor: 10 pontos

# %% [markdown]
# #### Alunos:
# -
# -
# -
# -
# -

# %% [markdown]
# ---
# #### Questão 1 — Operadores em Python
#
# Considere as variáveis abaixo:
#
# ```python
# pressao = 145
# limite = 140
#
# exames_ok = True
# alergia = False
#
# lista_a = [1, 2, 3]
# lista_b = lista_a
#
# resultado = None
# ```
#
# **a)** Use **operadores de comparação** (`>`, `>=`, `<`, `<=`) para verificar se a pressão está acima do limite.
#
# **b)** Use **operadores lógicos** (`and`, `or`, `not`) para verificar se o paciente pode ser operado.
#
# Condição:
#
# exames_ok deve ser True,
# alergia deve ser False
#
# **c)** Use **operadores de identidade** (`is`, `is not`) para verificar se lista_a e lista_b são o mesmo objeto.
#
# **d)** Usando **operadores de equivalência** (`==`, `!=`), verifique se `resultado` é igual a `None`.

# %% [markdown]
# #### Questão 2 — `for` com `enumerate`
#
# Dada a lista de pacientes abaixo, use um laço `for` com `enumerate` para exibir cada paciente com seu número sequencial (começando em 1), nome e idade.
#
# ```python
# pacientes = [
#     {'nome': 'Ana',    'idade': 34},
#     {'nome': 'Bruno',  'idade': 45},
#     {'nome': 'Carla',  'idade': 28},
#     {'nome': 'Daniel', 'idade': 52},
# ]
# ```
#
# **Requisitos:**
# - Use `enumerate` com `start=1`
# - Exiba uma linha por paciente no formato: `1. Ana — 34 anos`

# %% [markdown]
# ---
# #### Questão 3 — `for` com Dicionário
#
# Dado o dicionário de um paciente abaixo, use um laço `for` para percorrer e exibir cada campo com seu rótulo e valor.
#
# ```python
# paciente = {
#     'nome':      'Maria Silva',
#     'idade':     45,
#     'peso':      72.5,
#     'altura':    1.68,
#     'diabetes':  False,
#     'colesterol': 185,
# }
# ```
#
# **Requisitos:**
# - Use `for` com `.items()` para iterar sobre o dicionário
# - Exiba cada linha no formato: `nome: Maria Silva`
# - Para o campo `diabetes`, exiba `Sim` ou `Não`, substituindo o `True`/`False`, exibindo o dicionário corrigindo

# %% [markdown]
# ---
# #### Questão 4 — `for` com `if` / `elif` / `else`
#
# Dado o dicionário de pacientes abaixo, use um laço `for` para classificar a glicemia de cada paciente de acordo com a tabela clínica.
#
#
# ```python
# pacientes = {
#     "Ana": {"idade": 25, "peso": 58, "glicemia": 65},
#     "Carlos": {"idade": 42, "peso": 85, "glicemia": 92},
#     "Marina": {"idade": 31, "peso": 72, "glicemia": 110},
#     "João": {"idade": 50, "peso": 95, "glicemia": 180},
#     "Fernanda": {"idade": 28, "peso": 67, "glicemia": 130}
# }
# ```
#
# | Glicemia (mg/dL) | Classificação |
# |---|---|
# | menor que 70 | Hipoglicemia |
# | entre 70 e 99 | Normal |
# | entre 100 e 125 | Pré-diabetes |
# | maior ou igual a 126 | Diabetes |
#
# **Requisitos:**
# - Use `for` para percorrer o dicion´rio
# - Use `if`, `elif` e `else` para classificar cada valor
# - Exiba uma linha por valor no formato: `65 mg/dL → Hipoglicemia`
# - Adicione ao dicionário uma nova chave chamada "classificação" e seus valores e exiba o dicionário

# %% [markdown]
# ## Dado o código seguinte:
#
# ```python
# import time
#
# peso_texto = input("Digite o seu peso (kg): ")
# peso_texto = peso_texto.replace(',', '.')
# peso = float(peso_texto)
#
# print("Peso informado:", peso, "kg")
#
# altura_texto = input("Digite a sua altura (m): ")
# altura_texto = altura_texto.replace(',', '.')
# altura = float(altura_texto)
#
# print(f"Altura informada: {altura} m")
#
# print("\nCalculando o IMC...")
# time.sleep(2)
#
# altura_ao_quadrado = altura ** 2
# imc = peso / altura_ao_quadrado
#
# print(f"\nSeu IMC é: {imc:.2f}")
#
# ```

# %% [markdown]
# #### 5. Complete o código acima usando estruturas condicionais (`if`, `elif`, `else`) para mostrar a classificação do IMC.
#
# #### Regras
#
# | IMC | Classificação |
# |---|---|
# | menor que 18.5 | Abaixo do peso |
# | entre 18.5 e 24.9 | Peso normal |
# | entre 25 e 29.9 | Sobrepeso |
# | maior ou igual a 30 | Obesidade |

# %% [markdown]
# #### 6. Adicione tratamento de erros usando `try` e `except` no código acima
#
# O programa deve:
#
# - impedir que o usuário digite letras no peso ou altura
# - impedir divisão por zero
# - mostrar mensagens de erro amigáveis
#
# #### Regras
#
# - Use `try`
# - Use `except ValueError`
# - Use `except ZeroDivisionError`

# %% [markdown]
# #### 7. Modifique o programa para usar `while True`.
#
# O programa deve continuar calculando IMC até o usuário digitar:
#
# ```text
# sair
